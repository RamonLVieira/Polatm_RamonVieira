# %%
# Utilizando Pandas para abrir a planilha
import pandas as pd
import os

#Coletando o caminho da pasta que estou
cwd = os.getcwd()

#Pasta dos fatores de emissão
path = cwd+'\\tabelas\\FE'
print(path)

#Indicando nome do arquivo
chapterNumer = 10
subChapter = 5
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'
print(file)
#fe = pd.read_csv(path)

#Abrindo arquivo utilizadno o Pandas
fe = pd.read_csv(path + '\\'+file)
print(fe)
# Out:
# C:\Users\Dell\OneDrive\Documentos\GitHub\Polatm_RamonVieira\tabelas\FE
# chp_10_5.csv
#    CO  CO2    VOC    HF  Flurides
# 0   0  NaN    NaN   NaN       NaN
# 1   1  NaN    NaN   NaN       NaN
# 2   2  NaN    NaN   NaN       NaN
# 3   3  3.3  780.0  0.43      0.53

# %%
# Plotando os fatores de emissão
import matplotlib.pyplot as plt

atv = 1000 # Considerando uma taxa de atividade
emis = fe['CO']*atv

fig,ax = plt.subplots()
emis.plot.bar(ax=ax,x='Source')
# Out:
# <Axes: >
